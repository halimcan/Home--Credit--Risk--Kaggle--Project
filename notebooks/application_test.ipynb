# %%
# Installments of required tables
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#  BigQuery API activation
from google.colab import auth
auth.authenticate_user()

# %%
# big query add-on installation

# !pip install --quiet google-cloud-bigquery
from google.cloud import bigquery

# %%
# BigQuery client oluştur
client = bigquery.Client(project="homecredit-478707")

# Tabloyu BigQuery'den çek
query = """
SELECT *
FROM `homecredit-478707.Homecredit_Tables.application_test`
"""
application_test = client.query(query).to_dataframe()

# %%
application_test.info()

# %%
application_test.head(2)

# %% [markdown]
# # Feature Engineering
